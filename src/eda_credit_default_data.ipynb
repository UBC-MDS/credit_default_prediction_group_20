# %% [markdown]
# ## Exploratory Data Analysis of the Credit Card Payment Default Dataset

# %% [markdown]
# ### Import

# %%
import pandas as pd
import pandas as pd
import altair as alt
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import warnings

# ignore warning
warnings.filterwarnings('ignore')

# Save a vega-lite spec and a PNG blob for each plot in the notebook
alt.renderers.enable('mimetype')
# Handle large data sets without embedding them in the notebook
alt.data_transformers.enable('data_server')
# Out:
# DataTransformerRegistry.enable('data_server')

# %% [markdown]
# ### Read raw data set

# %%
# skip the first row, and make id column as index
credit_df = pd.read_excel("../data/raw/credit_default_data.xlsx", index_col=0, skiprows=1)

# change a column name
credit_df = credit_df.rename(columns={'default payment next month': 'default_payment_next_month'})

# change target data type
credit_df["default_payment_next_month"] = credit_df["default_payment_next_month"].astype("category")

# %% [markdown]
# ### Summary of the data set

# %% [markdown]
# The data file is available on UCI Machine Learning Repository. The dataset this project uses is the default of credit card payment by clients, created by I-Cheng Yeh from Department of Information Management, Chung Hua University, Taiwan. and Department of Civil Engineering, Tamkang University, Taiwan.
#
# The goal of the project is to predict whether a person would default on a credit card payment by analyzing various features in the dataset. There are 30,000 observations in the data set, 23 features, and a single target. There are no missing values in the data set. The target in the data is whether the client would default on the next month's payment.
#
# The columns include default payment as target, the value is 1 if yes, and 0 otherwise. The monthly bill statements in the last 6 months, monthly payment status in the last 6 months(on time, 1 month delay, 2 month delay, etc), monthly payment amount in the last 6 months, credit amount, gender, education, martial status, and age.

# %% [markdown]
# ### The data

# %% [markdown]
# Firstly, we just have a look at the data set. And get a sense of what it looks like. So making tables show the first few rows and the features' information.

# %%
credit_df.head()
# Out:
#     LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# ID
# 1       20000    2          2         1   24      2      2     -1     -1
# 2      120000    2          2         2   26     -1      2      0      0
# 3       90000    2          2         2   34      0      0      0      0
# 4       50000    2          2         1   37      0      0      0      0
# 5       50000    1          2         1   57     -1      0     -1      0
#
#     PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# ID         ...
# 1      -2  ...          0          0          0         0       689         0
# 2       0  ...       3272       3455       3261         0      1000      1000
# 3       0  ...      14331      14948      15549      1518      1500      1000
# 4       0  ...      28314      28959      29547      2000      2019      1200
# 5       0  ...      20940      19146      19131      2000     36681     10000
#
#     PAY_AMT4  PAY_AMT5  PAY_AMT6  default_payment_next_month
# ID
# 1          0         0         0                           1
# 2       1000         0      2000                           1
# 3       1000      1000      5000                           0
# 4       1100      1069      1000                           0
# 5       9000       689       679                           0
#
# [5 rows x 24 columns]

# %% [markdown]
# first few rows of data

# %% [markdown]
# ### Table 1: Feature Information

# %% [markdown]
# There is no missing value in our data set, and there is 30000 observations for each feature.

# %%
credit_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30000 entries, 1 to 30000
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   LIMIT_BAL                   30000 non-null  int64
#  1   SEX                         30000 non-null  int64
#  2   EDUCATION                   30000 non-null  int64
#  3   MARRIAGE                    30000 non-null  int64
#  4   AGE                         30000 non-null  int64
#  5   PAY_0                       30000 non-null  int64
#  6   PAY_2                       30000 non-null  int64
#  7   PAY_3                       30000 non-null  int64
#  8   PAY_4                       30000 non-null  int64
#  9   PAY_5                       30000 non-null  int64
#  10  PAY_6                       30000 non-null  int64
#  11  BILL_AMT1                   30000 non-null  int64
#  12  BILL_AMT2                   30000 non-null  int64
#  13  BILL_AMT3                   30000 non-null  int64
#  14  BILL_AMT4                   30000 non-null  int64
#  15  BILL_AMT5                   30000 non-null  int64
#  16  BILL_AMT6                   30000 non-null  int64
#  17  PAY_AMT1                    30000 non-null  int64
#  18  PAY_AMT2                    30000 non-null  int64
#  19  PAY_AMT3                    30000 non-null  int64
#  20  PAY_AMT4                    30000 non-null  int64
#  21  PAY_AMT5                    30000 non-null  int64
#  22  PAY_AMT6                    30000 non-null  int64
#  23  default_payment_next_month  30000 non-null  category
# dtypes: category(1), int64(23)
# memory usage: 5.5 MB

# %% [markdown]
# Table 1. summary table for the whole data set.

# %% [markdown]
# ### Table 2: Feature Description

# %% [markdown]
# The scale of our numeric features is varied. For example, 'LIMIT_BAL' has a mean of 167484 and a standard deviation of 129747. Additionally, for feature 'AGE', the mean is 35.485500 and the standard deviation is 9.217904. Therefore, we may need to change their scale when we are doing the model training.

# %%
credit_df.describe()
# Out:
#             LIMIT_BAL           SEX     EDUCATION      MARRIAGE           AGE  \
# count    30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean    167484.322667      1.603733      1.853133      1.551867     35.485500
# std     129747.661567      0.489129      0.790349      0.521970      9.217904
# min      10000.000000      1.000000      0.000000      0.000000     21.000000
# 25%      50000.000000      1.000000      1.000000      1.000000     28.000000
# 50%     140000.000000      2.000000      2.000000      2.000000     34.000000
# 75%     240000.000000      2.000000      2.000000      2.000000     41.000000
# max    1000000.000000      2.000000      6.000000      3.000000     79.000000
#
#               PAY_0         PAY_2         PAY_3         PAY_4         PAY_5  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      -0.016700     -0.133767     -0.166200     -0.220667     -0.266200
# std        1.123802      1.197186      1.196868      1.169139      1.133187
# min       -2.000000     -2.000000     -2.000000     -2.000000     -2.000000
# 25%       -1.000000     -1.000000     -1.000000     -1.000000     -1.000000
# 50%        0.000000      0.000000      0.000000      0.000000      0.000000
# 75%        0.000000      0.000000      0.000000      0.000000      0.000000
# max        8.000000      8.000000      8.000000      8.000000      8.000000
#
#        ...     BILL_AMT3      BILL_AMT4      BILL_AMT5      BILL_AMT6  \
# count  ...  3.000000e+04   30000.000000   30000.000000   30000.000000
# mean   ...  4.701315e+04   43262.948967   40311.400967   38871.760400
# std    ...  6.934939e+04   64332.856134   60797.155770   59554.107537
# min    ... -1.572640e+05 -170000.000000  -81334.000000 -339603.000000
# 25%    ...  2.666250e+03    2326.750000    1763.000000    1256.000000
# 50%    ...  2.008850e+04   19052.000000   18104.500000   17071.000000
# 75%    ...  6.016475e+04   54506.000000   50190.500000   49198.250000
# max    ...  1.664089e+06  891586.000000  927171.000000  961664.000000
#
#             PAY_AMT1      PAY_AMT2      PAY_AMT3       PAY_AMT4  \
# count   30000.000000  3.000000e+04   30000.00000   30000.000000
# mean     5663.580500  5.921163e+03    5225.68150    4826.076867
# std     16563.280354  2.304087e+04   17606.96147   15666.159744
# min         0.000000  0.000000e+00       0.00000       0.000000
# 25%      1000.000000  8.330000e+02     390.00000     296.000000
# 50%      2100.000000  2.009000e+03    1800.00000    1500.000000
# 75%      5006.000000  5.000000e+03    4505.00000    4013.250000
# max    873552.000000  1.684259e+06  896040.00000  621000.000000
#
#             PAY_AMT5       PAY_AMT6
# count   30000.000000   30000.000000
# mean     4799.387633    5215.502567
# std     15278.305679   17777.465775
# min         0.000000       0.000000
# 25%       252.500000     117.750000
# 50%      1500.000000    1500.000000
# 75%      4031.500000    4000.000000
# max    426529.000000  528666.000000
#
# [8 rows x 23 columns]

# %% [markdown]
# Table 2. numeric feataures summary (mean, std...)

# %% [markdown]
# ### Data Splitting

# %% [markdown]
# To carry out the EDA, we split the data in to 20% test set and 80% train set. Additionally, we are using random_state=522 to keep the results consist across runs. The following EDA will be based on the training data set.

# %%
train_df, test_df = train_test_split(credit_df, test_size=0.2, random_state=522)

# %%
train_df.head()
# Out:
#        LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# ID
# 23638     200000    2          2         2   46      0      0      0      0
# 17170      50000    2          3         2   26      0      0      0      0
# 15956     210000    2          1         2   30      0      0      0      0
# 21487      90000    2          1         2   27      0      0      2      0
# 12212      60000    1          2         1   40      0      0      0      0
#
#        PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# ID            ...
# 23638      0  ...     136629     139504     142269      4342      4593
# 17170      0  ...      26999      27748      28351      1700      2000
# 15956      0  ...       5125       5732       9297      2000      2500
# 21487      0  ...      50611      52764      55898      4000         0
# 12212      0  ...      22564      24191      25778      1500      1500
#
#        PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  default_payment_next_month
# ID
# 23638     14955      5143      5166      5349                           0
# 17170      3000      1500      1200      1136                           0
# 15956      2000      1000      4000      4000                           0
# 21487      3000      3000      4000      2043                           0
# 12212      2000      2000      2000      2000                           1
#
# [5 rows x 24 columns]

# %% [markdown]
# first few rows of train_df

# %% [markdown]
# ### Table 3: Proportion of Target Classes

# %% [markdown]
# Now, we need to know how many observation in each target class. In order to know, if we are working on an imbalanced data. So we can decide whether we should use some method to sovel the problem. The target (default payment next month) is an imbalanced feature. There are more cases of not defaulting than payment default. We may need to apply class-weight or another method to solve the problem.

# %%
Target_df = pd.DataFrame(credit_df['default_payment_next_month'].value_counts()).style.set_caption("Target Classes")
Target_df
# Out:
# <style type="text/css">
# </style>
# <table id="T_0cd1e">
#   <caption>Target Classes</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0cd1e_level0_col0" class="col_heading level0 col0" >default_payment_next_month</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0cd1e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0cd1e_row0_col0" class="data row0 col0" >23364</td>
#     </tr>
#     <tr>
#       <th id="T_0cd1e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0cd1e_row1_col0" class="data row1 col0" >6636</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Table 3. Number of observations for each of the two classes target.

# %% [markdown]
# ### Plot 1: Distribution Visualization of Numerical Features

# %% [markdown]
# After taking a closer look to the target, we also need to understand all the features. We can create a histogram to show the distribution of numerical features first. We need to get all numerical features for our data and make a histogram for each one of them. Then we can know the distribution for all numerical features. For each feature there is no overlap between the two target classes (this may due to the imbalance class distribution). However, we can clearly see that both classes have approximately the same distribution. For example, the distribution of 'AGE' for both classes is right skewed. Moreover, most of our numeric features are right-skewed. We may need to consider that when training the model. It hard to tell which numerical features are important.

# %%
num_cols = ["LIMIT_BAL", "AGE", "BILL_AMT1", "BILL_AMT2", "BILL_AMT3", "BILL_AMT4", 
            "BILL_AMT5", "BILL_AMT6", "PAY_AMT1",  "PAY_AMT2",  "PAY_AMT3", 
            "PAY_AMT4","PAY_AMT5", "PAY_AMT6"]

dv_plot = alt.Chart(train_df).mark_bar().encode(
     alt.X(alt.repeat(), type='quantitative', bin=alt.Bin(maxbins=30)),
     y='count()',
     color='default_payment_next_month'
).properties(
    width=200,
    height=150
).repeat(
    num_cols,
    columns=3
)

dv_plot = dv_plot.properties(
    title=alt.TitleParams(text='Distribution Visualization of Numerical Features')
)

dv_plot
# Out:
# <VegaLite 4 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %% [markdown]
# Plot 1: Comparing the distributions for numerical features with two classes of the target by histograms

# %% [markdown]
# ### Plot 2: Distribution Visualization of Categorical Features

# %% [markdown]
# Similarly, after taking a closer look to all the numerical features, we also need to understand all the categorical features. We can create bar plots to show the distributions of categorical features and separate them by the target classes. We need to get all categorical features for our data and make a bar plot for each one of them. Because of the problem of class imbalance, it is hard to tell which features is more important than others.

# %%
cat_col = ["EDUCATION", "MARRIAGE", "SEX", "PAY_0", "PAY_2", "PAY_3", "PAY_4", "PAY_5", "PAY_6"]

plot_cate = alt.Chart(train_df).mark_bar().encode(
     alt.X(alt.repeat(), type='quantitative', bin=alt.Bin(maxbins=10)),
     y='count()',
     color='default_payment_next_month'
).properties(
    width=200,
    height=150
).repeat(
    cat_col,
    columns=3
)

plot_cate = plot_cate.properties(
    title=alt.TitleParams(text='Distribution Visualization of Categorical Features')
)

plot_cate
# Out:
# <VegaLite 4 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %% [markdown]
# Plot 2: Comparing the distributions for categorical features with two classes of the target by histograms

# %% [markdown]
# ### Table 4 Correlation matrix

# %% [markdown]
# Then we go even deeper to explore the correlations of each pair of features and target. We are interested in which pair of the feature and target have a strong correlation. So we create a correlation matrix to show the corresponding correlation for each variable. Maybe we can get a sense of the feature importance. We can see that the 'PAY_0', 'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', and 'PAY_6' have a quite high correlation with each other. In addition, 'BILL_AMT1', 'BILL_AMT2', 'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', and 'BILL_AMT6' have the same issue. We may need to consider these when training the model. Additionally, as these features have a strong correlation with each other, we may need to consider dropping one of the pairs. For example, 'BILL_AMT1' and 'BILL_AMT2' have a correlation of 0.95, which is quite high.

# %%
train_df.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_79a2e_row0_col0, #T_79a2e_row1_col1, #T_79a2e_row2_col2, #T_79a2e_row3_col3, #T_79a2e_row4_col4, #T_79a2e_row5_col5, #T_79a2e_row6_col6, #T_79a2e_row7_col7, #T_79a2e_row8_col8, #T_79a2e_row9_col9, #T_79a2e_row10_col10, #T_79a2e_row11_col11, #T_79a2e_row12_col12, #T_79a2e_row13_col13, #T_79a2e_row14_col14, #T_79a2e_row15_col15, #T_79a2e_row16_col16, #T_79a2e_row17_col17, #T_79a2e_row18_col18, #T_79a2e_row19_col19, #T_79a2e_row20_col20, #T_79a2e_row21_col21, #T_79a2e_row22_col22 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_79a2e_row0_col1 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_79a2e_row0_col2, #T_79a2e_row0_col5, #T_79a2e_row0_col6, #T_79a2e_row0_col7, #T_79a2e_row0_col8, #T_79a2e_row0_col9, #T_79a2e_row0_col10, #T_79a2e_row1_col11, #T_79a2e_row1_col12, #T_79a2e_row1_col13, #T_79a2e_row1_col16, #T_79a2e_row3_col4, #T_79a2e_row3_col13, #T_79a2e_row3_col14, #T_79a2e_row3_col15, #T_79a2e_row3_col16, #T_79a2e_row4_col1, #T_79a2e_row4_col3, #T_79a2e_row5_col17, #T_79a2e_row5_col18, #T_79a2e_row5_col19, #T_79a2e_row5_col20, #T_79a2e_row5_col21, #T_79a2e_row5_col22, #T_79a2e_row6_col0, #T_79a2e_row6_col17, #T_79a2e_row8_col19 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_79a2e_row0_col3, #T_79a2e_row3_col10, #T_79a2e_row5_col11, #T_79a2e_row5_col12, #T_79a2e_row14_col22, #T_79a2e_row17_col16, #T_79a2e_row19_col20, #T_79a2e_row19_col21, #T_79a2e_row21_col17 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_79a2e_row0_col4, #T_79a2e_row13_col7, #T_79a2e_row15_col7, #T_79a2e_row16_col6, #T_79a2e_row16_col7, #T_79a2e_row22_col0 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_79a2e_row0_col11, #T_79a2e_row0_col15, #T_79a2e_row2_col7, #T_79a2e_row6_col3, #T_79a2e_row17_col4, #T_79a2e_row17_col12, #T_79a2e_row20_col15 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_79a2e_row0_col12 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_79a2e_row0_col13, #T_79a2e_row0_col16, #T_79a2e_row5_col3, #T_79a2e_row10_col15, #T_79a2e_row20_col4, #T_79a2e_row21_col4, #T_79a2e_row22_col4 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_79a2e_row0_col14, #T_79a2e_row13_col17, #T_79a2e_row18_col4, #T_79a2e_row19_col14 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_79a2e_row0_col17, #T_79a2e_row0_col21, #T_79a2e_row6_col11, #T_79a2e_row8_col13, #T_79a2e_row8_col14, #T_79a2e_row9_col13, #T_79a2e_row16_col17 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_79a2e_row0_col18, #T_79a2e_row1_col0, #T_79a2e_row10_col2, #T_79a2e_row10_col12, #T_79a2e_row19_col15, #T_79a2e_row19_col17, #T_79a2e_row21_col18 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_79a2e_row0_col19, #T_79a2e_row2_col9, #T_79a2e_row7_col2, #T_79a2e_row9_col16, #T_79a2e_row12_col3, #T_79a2e_row15_col17, #T_79a2e_row16_col3 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_79a2e_row0_col20, #T_79a2e_row0_col22, #T_79a2e_row5_col4, #T_79a2e_row6_col12, #T_79a2e_row7_col12, #T_79a2e_row8_col15, #T_79a2e_row10_col13 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_79a2e_row1_col2, #T_79a2e_row5_col16, #T_79a2e_row12_col2, #T_79a2e_row12_col19, #T_79a2e_row13_col19, #T_79a2e_row17_col21, #T_79a2e_row18_col9, #T_79a2e_row18_col22, #T_79a2e_row21_col6, #T_79a2e_row21_col7 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_79a2e_row1_col3, #T_79a2e_row5_col2 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_79a2e_row1_col4, #T_79a2e_row3_col5, #T_79a2e_row3_col9, #T_79a2e_row13_col21, #T_79a2e_row20_col19 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_79a2e_row1_col5, #T_79a2e_row1_col7, #T_79a2e_row4_col8, #T_79a2e_row12_col18, #T_79a2e_row20_col13, #T_79a2e_row22_col10 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_79a2e_row1_col6, #T_79a2e_row17_col11, #T_79a2e_row18_col7, #T_79a2e_row18_col20, #T_79a2e_row19_col11, #T_79a2e_row20_col12, #T_79a2e_row21_col5, #T_79a2e_row22_col5 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_79a2e_row1_col8, #T_79a2e_row21_col15 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_79a2e_row1_col9, #T_79a2e_row4_col9, #T_79a2e_row17_col5, #T_79a2e_row19_col2, #T_79a2e_row19_col5, #T_79a2e_row19_col8, #T_79a2e_row20_col2, #T_79a2e_row20_col9, #T_79a2e_row21_col2 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_79a2e_row1_col10, #T_79a2e_row4_col10, #T_79a2e_row20_col14, #T_79a2e_row21_col10 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_79a2e_row1_col14, #T_79a2e_row1_col15, #T_79a2e_row7_col0, #T_79a2e_row7_col18, #T_79a2e_row9_col20, #T_79a2e_row10_col21 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_79a2e_row1_col17, #T_79a2e_row4_col14, #T_79a2e_row10_col17, #T_79a2e_row10_col19, #T_79a2e_row19_col1, #T_79a2e_row20_col1 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_79a2e_row1_col18, #T_79a2e_row1_col19, #T_79a2e_row4_col16, #T_79a2e_row10_col18, #T_79a2e_row14_col1 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_79a2e_row1_col20, #T_79a2e_row1_col22, #T_79a2e_row3_col21, #T_79a2e_row3_col22, #T_79a2e_row10_col0 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_79a2e_row1_col21, #T_79a2e_row2_col12, #T_79a2e_row3_col18, #T_79a2e_row11_col1, #T_79a2e_row12_col1 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_79a2e_row2_col0, #T_79a2e_row2_col11, #T_79a2e_row3_col1 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_79a2e_row2_col1, #T_79a2e_row4_col17, #T_79a2e_row4_col19 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_79a2e_row2_col3, #T_79a2e_row12_col20, #T_79a2e_row13_col2, #T_79a2e_row13_col20, #T_79a2e_row17_col9, #T_79a2e_row18_col16, #T_79a2e_row20_col6, #T_79a2e_row20_col21, #T_79a2e_row20_col22, #T_79a2e_row22_col7, #T_79a2e_row22_col14, #T_79a2e_row22_col21 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_79a2e_row2_col4, #T_79a2e_row14_col9, #T_79a2e_row16_col10 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_79a2e_row2_col5, #T_79a2e_row2_col8, #T_79a2e_row10_col16 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_79a2e_row2_col6, #T_79a2e_row16_col4 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_79a2e_row2_col10, #T_79a2e_row3_col6, #T_79a2e_row3_col7, #T_79a2e_row6_col4, #T_79a2e_row7_col4, #T_79a2e_row8_col12, #T_79a2e_row9_col4, #T_79a2e_row9_col12 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_79a2e_row2_col13, #T_79a2e_row2_col18, #T_79a2e_row9_col0 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_79a2e_row2_col14, #T_79a2e_row8_col0, #T_79a2e_row8_col1, #T_79a2e_row8_col22, #T_79a2e_row9_col21 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_79a2e_row2_col15, #T_79a2e_row2_col22, #T_79a2e_row5_col0, #T_79a2e_row6_col20, #T_79a2e_row6_col21, #T_79a2e_row6_col22, #T_79a2e_row7_col19, #T_79a2e_row7_col22, #T_79a2e_row8_col20 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_79a2e_row2_col16, #T_79a2e_row6_col18 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_79a2e_row2_col17, #T_79a2e_row3_col20 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_79a2e_row2_col19, #T_79a2e_row9_col1 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_79a2e_row2_col20, #T_79a2e_row7_col1, #T_79a2e_row7_col21, #T_79a2e_row8_col21 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_79a2e_row2_col21, #T_79a2e_row3_col11, #T_79a2e_row3_col12, #T_79a2e_row6_col1, #T_79a2e_row6_col19, #T_79a2e_row7_col20 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_79a2e_row3_col0 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_79a2e_row3_col2, #T_79a2e_row3_col17, #T_79a2e_row3_col19, #T_79a2e_row4_col22, #T_79a2e_row8_col17, #T_79a2e_row9_col18, #T_79a2e_row15_col1, #T_79a2e_row16_col1 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_79a2e_row3_col8, #T_79a2e_row6_col16, #T_79a2e_row7_col11, #T_79a2e_row7_col16, #T_79a2e_row17_col15, #T_79a2e_row18_col21, #T_79a2e_row19_col18 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_79a2e_row4_col0, #T_79a2e_row14_col19, #T_79a2e_row16_col21 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_79a2e_row4_col2

# %% [markdown]
# Table 4. Correlation matrix for all features and target. The heatmap for correlations.
